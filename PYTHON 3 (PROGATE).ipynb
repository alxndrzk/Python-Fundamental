# %% [markdown]
# **FUNCTION**
#
# Function tidak akan dijalankan hanya dengan mendefinisikannya, Anda perlu memanggil function untuk menjalankan code didalamnya. Untuk memanggil sebuah function, Anda cukup menulis function_name(). Perlu diingat bahwa function hanya dapat dipanggil setelah Anda mendefinisikannya.

# %%
def greet():
  print('halo')
greet()

#ex
# Definisikan function print_hand 
def print_hand():
    print('Anda memilih: Batu')

# Panggil function print_hand 
print_hand()
# Out:
# halo

# %% [markdown]
# **FUNCTION DENGAN ARGUMENT**
#
# Untuk memberikan argument ke sebuah function, function harus mempunyai variable untuk menerimanya, variable ini di sebut parameter. Pada contoh di bawah, function greet memiliki parameter name untuk menerima sebuah argument.
#
# Kita bisa memberikan argument dengan memanggil sebuah function dengan: function_name(argument). Saat function dipanggil, argument yang diberikan akan ditentukan ke parameter untuk digunakan di dalam function.

# %%
def greet(name): #greet adalah function sedangkan name adalah parameter
   print("halo " + name)
greet("john")
greet('Gultom')


#ex
# Tambahkan parameter untuk print_hand
def print_hand(pilihan):
    # Gunakan parameter untuk mencetak 'Anda memilih: ___'
    print('Anda memilih: ' + pilihan)

# Panggil print_hand dengan 'Batu'
print_hand('Batu')

# Panggil print_hand dengan 'Kertas'
print_hand('Kertas')
# Out:
# halo john
# halo Gultom
# Anda memilih: Batu
# Anda memilih: Kertas

# %% [markdown]
# **FUNCTION DENGAN BANYAK PARAMETER**
#
# Anda dapat menambahkan banyak parameter ke sebuah function dengan memisahkan parameter tersebut dengan tanda koma ,.
# Pada contoh dibawah, name adalah parameter pertama, dan message adalah parameter kedua

# %%
def greet(name, message):
  print(name + ', ' + message)
greet('alex', 'selamat datang') #alex sebagai name, wajib dikasih tanda "," lalu selamat datang sebagai message

#ex
# Tambahkan parameter ke print_hand
def print_hand(hand, name):
    # Ubah hasil ke '___ memilih: ___'
    print(name  +' memilih: ' + hand)

# Tambahkan argument ke dua ke print_hand
print_hand('Batu', 'Ninja Ken')

# Tambahkan argument ke dua ke print_hand
print_hand('Kertas', 'Komputer')
# Out:
# alex, selamat datang

# %% [markdown]
# **NILAI DEFAULT PARAMETER**
#
# Anda dapat mengatur nilai default parameter.
# Nilai default akan digunakan ketika tidak ada argument yang disediakan untuk parameter

# %%
def greet(name, message='Senang bertemu dengan anda'): #senang bertemu dengan anda adalah default parameter
  print(name + ', ' + message)
greet("john")
greet('john', 'salam kenal')

#ex
# Tambahkan nilai default untuk name
def print_hand(hand, name='Tamu'):
    print(name + ' memilih: ' + hand)

# Tambahkan argument ke print_hand
print_hand("Batu")
# Out:
# john, Senang bertemu dengan anda
# john, salam kenal
# Tamu memilih: Batu

# %% [markdown]
# **NILAI RETURN**
#
# Saat kita ingin menggunakan hasil dari sebuah function, kita dapat menggunakan return. Pada contoh di bawah, function add menjadikan 3 dan 7 sebagai argument, dan mengembalikan 10 ke pemanggilnya

# %%
def add(a, b):
  return a+b
sum = add(1, 4)
print(sum)
# Out:
# 5

# %% [markdown]
# **LIBRARY STANDAR PYTHON**
#
# MATH = module untuk kalkulasi kompleks
#  - sin()
#  - cos()
#  - tan()
#
#
# RANDOM = module untuk menghasilkan nilai acak
#   - random()
#   - randint()
#   - shuffle()
#
# DATETIME = module untuk data waktu dan tanggal
#  - date()
#  - time()
#  - datetime()

# %% [markdown]
# **MEMBUAT PROGRAM SEDERHANA BATU GUNTING KERTAS**

# %%
def validate(hand):
  if hand < 0 or hand > 2:
    return False
  return True


def print_hand(hand, name="Tamu"):
  hands  = ["Batu",  'Gunting', 'Kertas']
  print(name + " memilih: " + hands[hand])


def judge(player, komputer):
 if player == komputer:
   return 'Seri'
 elif player == 0 and komputer == 2:
   return "kalah"
 elif player == 1 and komputer == 0:
   return 'Kalah'
 elif player == 2 and komputer == 1:
   return 'Kalah'
 else :
   return "Menang"


print('Memulai Permainan Batu Gunting Kertas!)')
player_name = input('Masukkan nama anda: ')


print('Pilihlah salah satu (0: Batu, 1:Gunting, 2:Kertas)')
player_hand = int(input("Masukkan nomor (0-2)"))


if validate(player_hand) :
   computer_hand = random.randint(0, 2)

   print_hand(player_hand, player_name)
   print_hand(computer_hand, 'Komputer')

   result = judge(player_hand, computer_hand)
   print('Hasil: ' + result)
else:
  print('Masukkan nomor yang benar')
# Out:
# Memulai Permainan Batu Gunting Kertas!)
# Masukkan nama anda: 0
# Pilihlah salah satu (0: Batu, 1:Gunting, 2:Kertas)
# Masukkan nomor (0-2)0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5614a400503b> in <module>()
#      32
#      33 if validate(player_hand) :
# ---> 34    computer_hand = random.randint(0, 2)
#      35
#      36    print_hand(player_hand, player_name)
#
# NameError: name 'random' is not defined

# %%
# Definisikan function validate 
def validate (hand):
    # Tambahkan control flow berdasarkan nilai hand
    if hand < 0 or hand > 2 :
        return False
        return True

def print_hand(hand, name='Tamu'):
    hands = ['Batu', 'Kertas', 'Gunting']
    print(name + ' memilih: ' + hands[hand])

print('Memulai permainan Batu Kertas Gunting!')
player_name = input('Masukkan nama Anda: ')

print('Pilih tangan: (0: Batu, 1: Kertas, 2: Gunting)')
player_hand = int(input('masukkan nomor (0-2): '))

# Tambahkan control flow berdasarkan nilai return dari function validate 
if validate(player_hand) :
    print_hand(player_hand, player_name)
else :
    print("Mohon masukkan nomor yang benar")
# Out:
# Memulai permainan Batu Kertas Gunting!
# Masukkan nama Anda: Alex
# Pilih tangan: (0: Batu, 1: Kertas, 2: Gunting)
# masukkan nomor (0-2): 1
# Mohon masukkan nomor yang benar
